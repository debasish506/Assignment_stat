# %% [markdown]
# Question 1: What is the difference between descriptive statistics and inferential
# statistics? Explain with examples.
# Ans Descriptive statistics is use to calculated the mean , median , mode of data set to analysices the result.
#     2. It is take whole data set into consederation
#     3. skewness, Variance and standard deveation are basic tool to study the data
#     4. it give the result of existing data
#     eg. Avg score of online class , Number of student complet the daily leacture
#
#   2) INferential Statistics
#       it is used for take the sample data and give the result on the basics of this ,
#       1. used to measure the large data set or give the prediction data
#       eg . tree count in a forest
# Question 2: What is sampling in statistics? Explain the differences between random
# and stratified sampling.
#     1. Sampaling : for study we select a smal guoup of element form the data set is called sampaling
#     Randaom Smapling:
#      Here teh selection of data set is randaom and each data set of eaual chance of selection.
#      eg . select 10 student among the 100 student
#           Geting one numner when rolling a dice
#       key :where data set are uniformly present
#     Stratified Smapling:
#       here we make a gorup of with sapecific propery to study the data
#       1. for that clear and proper data information is need
#       2. use for spectifici study porpose
# Question 3: Define mean, median, and mode. Explain why these measures of central
# tendency are important.
#     Mean: it is the average of given data set.
#     1. eg Data=[1,2,3,4,5,6]
#     mean =(1+2+3+4+5+6)/6=3.166
#     Median: It is defined as after arranging the data in assending oreder then after find out the middle most part . if it is odd no of data then we get one , if it is even no of data then we add two middle element and devided by 2
#     Mode: In show heighest no of frequency or given data set
#
#   By these stattistical menthod we came to know the skewness of normal distriburion curve .
#
# Question 4: Explain skewness and kurtosis. What does a positive skew imply about the data?
#
#  Ans: Skewness: it refer the normal distribution curve is prolonged in one side then sekeness observed , basically it refer the more no of data set is present in that direction , Righ hand skew and left hand skewness is there.

# %%
#Question 5: Implement a Python program to compute the mean, median, and mode of a given list of numbers.
numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]

# %%
import statistics

# %%
Mean=statistics.mean(numbers)
Median=statistics.median(numbers)
Mode=statistics.mode(numbers)
print(Mean)
print(Median)
print(Mode)
# Out:
# 19.6
# 19
# 12

# %%
#Question 6: Compute the covariance and correlation coefficient between the following two datasets provided as lists in Python:
list_x = [10, 20, 30, 40, 50]
list_y = [15, 25, 35, 45, 60]

import seaborn as sns
import pandas as pd

df = pd.DataFrame({'X': list_x, 'Y': list_y})
cov=df.cov(numeric_only=True)
Cor=df.corr(numeric_only=True)
print(cov)
print(Cor)
# Out:
#        X      Y
# X  250.0  275.0
# Y  275.0  305.0
#           X         Y
# X  1.000000  0.995893
# Y  0.995893  1.000000

# %%
#Question 7: Write a Python script to draw a boxplot for the following numeric list and identify its outliers. Explain the result:
data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]
import matplotlib.pyplot as plt

data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]
plt.boxplot(data)
plt.title("Boxplot of Data")
plt.show()
